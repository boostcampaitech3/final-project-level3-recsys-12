# %%
import requests
from bs4 import BeautifulSoup

url = 'https://jjalbang.today/emotionview/%ED%96%89%EB%B3%B5/924'

response = requests.get(url)

if response.status_code == 200:
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    img = soup.select('#아이디명')

else : 
    print(response.status_code)


# img = soup.find_all(class_='_img')

# n = 1
# for i in img: # 이미지를 50개 저장하기 위한 반복문
#     imgUrl = i['data-source'] 
#     with urlopen(imgUrl) as f:
#         with open('./img/' + plusUrl + str(n)+'.jpg','wb') as h: # 이미지 + 사진번호 + 확장자는 jpg
#             img = f.read() #이미지 읽기
#             h.write(img) # 이미지 저장
#     n += 1
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="width=device-width, initial-scale=1.0, user-scalable=no, height=device-height, maximum-scale=1.0, target-densityDpi=device-dpi" name="viewport"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="ad88552312d8df6ec22335ee7eb83ab167f7689b" name="naver-site-verification"/>
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방" name="title"/>
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 짤방 화남 웃음 좋아 황당 놀람 닥쳐 그만 멘붕 안습 놀림 칭찬 눈물 오글 부끄러움 철컹 움짤 오덕 오늘의짤방" name="description"/>
# <meta content="행복 - 상황별 짤방 모음 화남 웃음 좋아 황당 놀람 닥쳐 그만 멘붕 안습 놀림 칭찬 눈물 오글 부끄러움 철컹 움짤, 패러디,야당,자유당,정치,이게,새누리,때문이다,다,야당때문이다,바른정당,쓰레기,표정,만화,움짤,황당,김정은,북한,모습,무한도전,여자,닥쳐,분노,놀람,박근혜,눈빛,짤방,무도,대통령,바른,눈물,유재석,웃음,안습,박명수,고양이,애니,강아지,냥이,꺼져,깜놀,열받아,손가락,짜증,병맛,칭찬,왜,이,담배,궁물당,국민의당,조작의당,넘어지는,초등학교당,초딩당,국당,웃는,좋아,장면,귀여운,만능짤,개소리,아이,뭐야,싫어,어이없음,돼지,욕,그림,미친,이건,여기" name="keywords"/>
# <meta content="jjalbang.today" name="author"/>
# <meta content="jjalbang.today" name="generator"/>
# <meta content="오늘의짤방 - jjalbang.today" property="og:site_name">
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방" property="og:title">
# <meta content="https://jjalbang.today/jjveU.jpg" property="og:image">
# <meta content="summary_large_image" name="twitter:card">
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방" name="twitter:title">
# <meta content="https://jjalbang.today/jjveU.jpg" name="twitter:image"/>
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방" itemprop="name"/>
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 짤방 화남 웃음 좋아 황당 놀람 닥쳐 그만 멘붕 안습 놀림 칭찬 눈물 오글 부끄러움 철컹 움짤 오덕 오늘의짤방" itemprop="description"/>
# <meta content="https://jjalbang.today/jjveU.jpg" itemprop="image"/>
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방" name="nate:title"/>
# <meta content="오늘의짤방 - jjalbang.today" name="nate:site_name"/>
# <meta content="http://jjalbang.today" name="nate:url"/>
# <meta content="https://jjalbang.today/jjveU.jpg" name="nate:image">
# <meta content="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 짤방 화남 웃음 좋아 황당 놀람 닥쳐 그만 멘붕 안습 놀림 칭찬 눈물 오글 부끄러움 철컹 움짤 오덕 오늘의짤방" name="nate:description"/>
# <link href="/img/jjalbang.today.192x192.png" rel="icon" sizes="192x192"/>
# <link href="/img/jjalbang.today.128x128.png" rel="icon" sizes="128x128"/>
# <link href="/img/jjalbang.today.128x128.png" rel="apple-touch-icon" sizes="128x128"/>
# <link href="/img/jjalbang.today.128x128.png" rel="apple-touch-icon-precomposed" sizes="128x128"/>
# <link href="/img/jjalbang.today.128x128.png" rel="apple-touch-startup-image">
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <!-- link href="https://fonts.googleapis.com/css2?family=Nanum+Gothic:wght@100;200;400;700&display=swap" rel="stylesheet" -->
# <link href="/css/font.css?t=2022043011" rel="stylesheet"/>
# <link crossorigin="anonymous" href="//use.fontawesome.com/releases/v5.7.1/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" rel="stylesheet"/>
# <link crossorigin="anonymous" href="//cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.4.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link crossorigin="anonymous" href="//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.css" rel="stylesheet"/>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/jquery/2.2.4/jquery.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.4.1/js/bootstrap.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/clipboard.js/2.0.6/clipboard.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/jqueryui/1.11.4/jquery-ui.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/jqueryui-touch-punch/0.2.3/jquery.ui.touch-punch.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/jquery.form/4.3.0/jquery.form.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/eModal/1.2.69/eModal.min.js" type="text/javascript"></script>
# <script crossorigin="anonymous" src="//cdnjs.cloudflare.com/ajax/libs/bootbox.js/5.4.0/bootbox.min.js" type="text/javascript"></script>
# <script src="//openmain.pstatic.net/js/openmain.js" type="text/javascript"></script>
# <script src="//www.gstatic.com/charts/loader.js" type="text/javascript"></script>
# <script src="/js/comm.js?t=202204301153" type="text/javascript"></script>
# <script src="/js/upload.js?t=202204301153" type="text/javascript"></script>
# <script src="/js/lazyload.min.js" type="text/javascript"></script>
# <title>짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기 - 상황별 짤방 모음 오늘의짤방</title>
# <style>
# body {font-family: "Nanum Gothic", sans-serif;font-size:12px}
# .gal {padding-left:2px;padding-right:2px}
# .gal img{width: 100%; max-width:250px}
# .tag {text-align:center}
# .tag a{padding:6px;margin-bottom:3px;margin-left:3px}
# .tag_select {background-color:#47282A;color:#FFE600;font-size:12px;font-weight:bold}
# .msg_center {display:none;position:fixed;bottom:0px;width:100%;padding:20px;z-index:999;overflow:hidden; background-color:#513D3E;text-align:center;color:#FEF419;border: 1px solid #BEB0A8;}
# #mask { position:absolute; z-index:100; background-color:#000; display:none; left:0; top:0; }
# #fixed-menu {
#   width: 100%;
#   z-index:99;
#   position: fixed;
#   top: 0px;
#   left: 0px;
# }
# a {color:#555555}
# a:link {text-decoration: none}
# a:visited {text-decoration: none}
# a:hover {text-decoration: none}
# a:active {text-decoration: none}
# .btn-group button{padding:6px;max-width:80px;font-size:12px}
# .panel-heading {padding:3px}
# .panel-body {padding:5px}
# .panel-default {max-width:680px}
# .sub_select {font-weight:bold;background-color:#0489B1;color:#ffffff}
# .sub_select a{color:#ffffff}
# .menu_shadow {
# max-width: auto;
# box-shadow: 2px 2px 4px grey;
# }
# .container_menu {padding-left:6px;padding-right:6px}
# .table {margin-bottom:5px}
# .table-bordered {}
# .table-padding {padding:10px;}
# .table-padding .btn-padding{padding-top:12px;padding-bottom:12px;height:auto; text-align:center;vertical-align:middle}
# .btn-default-tag {border: 2px solid #ffffff;border-radius: 0px;background-color:#2e6b6a;color:#ffffff;font-weight:bold;padding:10px}
# .btn-default-s-tag {border: 1px solid #cccccc;border-radius: 0px;background-color:#2e6b6a;color:#ffffff;font-weight:none;padding:4px}
# .top_a_img {width:24px;background-image: url('/img/starbucks-24.png'); background-repeat: no-repeat; background-position: 50% 50%}
# .modal,modal-dialog{border-radius: 0px; }
# .modal.left .modal-dialog,
# .modal.right .modal-dialog {
# position: fixed;
# margin: auto;
# width: 250px;
# height: 100%;
# -webkit-transform: translate3d(0%, 0, 0);
# -ms-transform: translate3d(0%, 0, 0);
# -o-transform: translate3d(0%, 0, 0);
# transform: translate3d(0%, 0, 0);
# }
# .modal.left .modal-content,
# .modal.right .modal-content {height: 100%;overflow-y: auto;}
# .modal.left .modal-body,
# .modal.right .modal-body {padding: 15px 15px 80px;}
# /*Left*/
# .modal.left.fade .modal-dialog{
# left: -250px;
# -webkit-transition: opacity 0.1s linear, left 0.1s ease-out;
# -moz-transition: opacity 0.1s linear, left 0.1s ease-out;
# -o-transition: opacity 0.1s linear, left 0.1s ease-out;
# transition: opacity 0.1s linear, left 0.1s ease-out;
# }
# .modal.left.fade.in .modal-dialog{left: 0;}
# /*Right*/
# .modal.right.fade .modal-dialog {
# right: -250px;
# -webkit-transition: opacity 0.1s linear, right 0.1s ease-out;
# -moz-transition: opacity 0.1s linear, right 0.1s ease-out;
# -o-transition: opacity 0.1s linear, right 0.1s ease-out;
# transition: opacity 0.1s linear, right 0.1s ease-out;
# }
# .modal.right.fade.in .modal-dialog {right: 0;}
# .modal-content {
# border-radius: 0;
# border: none;
# }
# .modal-header {
# border-bottom-color: #EEEEEE;
# background-color: #FAFAFA;
# }
# .in-btn {background-color:#ffffff;border: 1px solid #555555;border-radius: 5px;padding:3px;cursor:pointer}
# .in_help_box{background-color:#ffffff;border: 1px solid #cccccc;border-radius: 5px;padding:10px}
# .in_help_box .fontsize {font-size:14px}
# .in_help_box .title {font-weight:bold}
# .in_help_box .fontsizesmall{font-size:12px}
# .cpointer{cursor:pointer}
# .bottom_info {max-width:500px;}
# .bottom_info .info_box {border-top: 1px solid #dddddd;border-bottom: 0px solid #dddddd;border-left: 1px solid #dddddd;border-right: 1px solid #dddddd;border-radius: 0px;padding:10px;margin-bottom:0px}
# .bottom_info .info_title {font-weight:bold;padding-right:3px;font-size:13px}
# .bottom_info .info_doc {color:#666666;font-size:13px}
# .bottom_info .info_box_bottom {border-bottom: 1px solid #dddddd;}
# .jjalbang_content{
#          position: absolute;
#          top:50%;
#          left:50%;
#          transform: translate(-50%, -50%);
#          font-size:5rem;
#          color: white;
#          z-index: 2;
#          text-align: center;
#     }
#
# .jjalbang_content_bottom{
#          position: absolute;
# 		 width:100%;
#          bottom:-45px;
#          left:50%;
#          transform: translate(-50%, -50%);
#          font-size:5rem;
#          color: white;
#          z-index: 1;
#          text-align: center;
#     }
#
# 	    .img-cover{
#        position: absolute;
#        height: 100%;
#        width: 100%;
#        background-color: rgba(0, 0, 0, 0.7);
#        z-index:1;
#     }
#
# </style>
# <script>
# function search_bbs(e,mode)
# {
# 	var tag = $("#bbsrq").val();
# 	var ev =  e.keyCode;
#
# 	if((ev == 13 && mode == "key") || mode == "click")
# 	{
# 		$(location).attr('href','/tag/'+tag);
# 	}
# }
#
# function search_bbs_bar(e,mode)
# {
# 	var tag = $("#bbsrq_bar").val();
# 	var ev =  e.keyCode;
#
# 	if((ev == 13 && mode == "key") || mode == "click")
# 	{
# 		$(location).attr('href','/tag/'+tag);
# 	}
# }
#
#
# function jjalbang_reg()
# {
# 	if($("#jjalbang_reg").css("display") == "none")
# 	{
# 		$("#jjalbang_reg").show();
# 		$('#jjalbtn').val("닫기");
# 	}
# 	else
# 	{
# 		$("#jjalbang_reg").hide();
# 		$('#jjalbtn').val("짤방등록");
# 	}
# }
#
# function msgAlert(id,msg,delay,fade)
# {
# 	$('#'+id).empty();
# 	if(delay)
# 	{
# 		$('#'+id).html(msg).show().delay(delay).fadeOut(fade);
# 	}
# 	else
# 	{
# 		$('#'+id).html(msg).show();
# 	}
# }
#
# function goBack()
# {
#     window.history.back();
# }
# </script>
# </link></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <div id="mask"></div>
# <script>
# $("#reloadwait").hide();
# $(document).ready(function (){
# $(window).scroll(function (){
# if($(window).scrollTop() <= -20){
#     //$("#reloadwait").html('새로고침중...').show();
# 		//location.reload();
# }
# });
# });
# </script>
# <div align="center" id="upload_div" style="position: fixed;width:100%;top:80px;display:none;z-index:101;padding:10px">
# <div align="center">
# <div class="panel panel-default">
# <div class="panel-heading">
# <div class="row" style="padding:5px">
# <span style="float:left;padding-left:10px"><strong>업로드</strong></span>
# <span style="float:right;padding-right:10px"><span onclick="upload_close()"><i class="fas fa-lg fa-times-circle cpointer"></i></span>
# </span></div>
# </div>
# <div class="panel-body" style="clear:both;padding:15px">
# <div style="font-size:12px;padding:4px">jpg, png, gif file only</div>
# <div style="font-size:12px;padding:4px">Up to 10 MB (짤방 만들기용은 200px 이상 자동 리사이즈)</div>
# <div align="center" id="image_upload">
# <form action="/ajax/upload.php" autocomplete="off" enctype="multipart/form-data" id="c_upload_file_jjalbang" method="post" name="c_upload_file_jjalbang">
# <input id="adr_code" name="adr_code" type="hidden"/>
# <input id="mode" name="mode" type="hidden" value="jjalbang"/>
# <input class="input_file upload" id="c_file" name="c_file" onchange="ajax_jjalbang_upload('https://jjalbang.today')" style="display:none;" type="file"/>
# <button class="btn btn-sm btn-default" id="btn-upload"><i class="fas fa-paperclip"></i> 이미지 선택 <span id="upload_loading" style="padding-top:5px;"></span></button> <span class="btn btn-sm btn-default" onclick="upload_close()">닫기</span>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div align="center" style="padding:0px">
# <div style="width:auto;padding-bottom:1px;text-align:center"><div id="c_file_print"></div></div>
# </div>
# </div>
# <div class="modal right fade" id="MainMenuModal">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><i class="fas fa-times" style="width:16px"></i></button> 오늘의짤방
# 		</div>
# <div style="padding:10px">
# <div style="background-color:#ffffff;border: 0px solid #cccccc;padding:7px;border-radius: 5px">
# <form action="/ajax/ajax.MemberLogin.php" autocomplete="off" id="memberlogin_outline" method="post" name="memberlogin_outline" style="width:100%">
# <div class="input-group">
# <span class="input-group-addon" id="basic-addon3"><i class="fas fa-user"></i></span>
# <input class="form-control input-sm required" id="in_email_login" maxlength="60" name="in_email" placeholder="Email" required="" style="padding:14px;" type="text"/>
# </div>
# <div class="input-group" style="margin-top:5px">
# <span class="input-group-addon" id="basic-addon3"><i class="fas fa-lock"></i></span>
# <input class="form-control input-sm required" id="in_password_login" maxlength="60" name="in_password" placeholder="Password" required="" style="padding:14px" type="password"/>
# </div>
# <div class="text-center" style="margin-top:10px;margin-bottom:4px">
# <input name="returnurl" type="hidden" value="https://jjalbang.today/emotionview/%ED%96%89%EB%B3%B5/924"/>
# <button accesskey="s" class="btn btn-sm btn-primary" id="btn_submit" type="submit"><span id="submit_loading_outline"></span><i aria-hidden="true" class="fa fa-check"></i> 로그인</button>
# <a class="btn btn-sm btn-default" onclick="$(location).attr('href','/?act=member.join');">회원가입</a>
# </div>
# </form>
# </div>
# <script>
# $(function(){
# 	$('#memberlogin_outline').ajaxForm({
#         dataType : 'html',
# 		beforeSerialize: function()
# 		{
# 		},
# 		beforeSubmit : function()
# 		{
# 			$('#submit_loading_outline').html("<img src='/img/wait_icon.gif' style='width:20px'>");
# 		},
# 		success : function(data) {
# 			var split_res = data.split('|');
# 			switch(split_res[0])
# 			{
# 				case "300" :
# 					bootbox.alert({message: split_res[1],size: 'small'});
# 					break;
# 				case "200" :
#
# 				bootbox.alert({
# 				message: split_res[1],
# 				size:'small',
# 				callback: function () {
# 						if(split_res[2])
# 						{
# 							$(location).attr('href',split_res[2]);
# 						}
# 						else
# 						{
# 							$(location).attr('href','/');
# 						}
# 					}
# 				});
#
# 					break;
# 				default :
# 					bootbox.alert({message: "오류가 발생했습니다. 잠시 후 다시 시도해 주세요.",size: 'small'});
# 					break;
# 			}
# 			$('#submit_loading_outline').empty();
# 		}
# 	});
# });
# </script>
# <div style="margin-top:7px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/?act=board.list');"><a href="/?act=board.list&amp;cat=1"><i class="fas fa-angle-right"></i> 자유게시판</a></td></tr>
# </table>
# </div>
# <div style="margin-top:7px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/');"><a href="/"><i class="fas fa-angle-right"></i> 이미지짤</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/emoticon');"><a href="/emoticon"><i class="fas fa-angle-right"></i> 텍스트+이모티콘짤</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/jjalbangfonts');"><a href="/jjalbangfonts"><i class="fas fa-angle-right"></i> 폰트짤방</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/action/rand_jjalbang.php');"><a href="/action/rand_jjalbang.php"><i class="fas fa-angle-right"></i> 랜덤짤방</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/jjalmakesiba');"><a href="/jjalmakesiba"><i class="fas fa-angle-right"></i> 짤방만들기</a></td></tr>
# </table>
# </div>
# <div style="margin-top:13px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/hateword');"><a href="/hateword"><i class="fas fa-angle-right"></i> 혐오단어 검출기</a></td></tr>
# </table>
# </div>
# <div style="margin-top:13px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/yearage');"><a href="/yearage"><i class="fas fa-angle-right"></i> 년도별 띠 / 나이</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/adultcheck');"><a href="/adultcheck"><i class="fas fa-angle-right"></i> 성년ㆍ미성년 나이 계산기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/?act=insta.today');"><a href="/?act=insta.today"><i class="fas fa-angle-right"></i> 오늘며칠?</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/myip');"><a href="/myip"><i class="fas fa-angle-right"></i> 내 아이피(IP) 주소</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/encode');"><a href="/encode"><i class="fas fa-angle-right"></i> 각종 Encode/Decode 변환</a></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/webcamtest');"><a href="/webcamtest"><i class="fas fa-angle-right"></i> 웹캠 테스트</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/screen');"><a href="/screen"><i class="fas fa-angle-right"></i> 내 모니터 해상도 확인</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/imagepress');"><a href="/imagepress"><i class="fas fa-angle-right"></i> 이미지 용량 줄이기</a></td></tr>
# </table>
# </div>
# <div style="margin-top:13px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/colorblindtest');"><a href="/colorblindtest"><i class="fas fa-angle-right"></i> 색맹 테스트</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/colorgreenblindtest');"><a href="/colorgreenblindtest"><i class="fas fa-angle-right"></i> 적록 색맹 / 색약 테스트</a> <span style="color:red">New</span></td></tr>
# </table>
# </div>
# <div style="margin-top:13px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchGirlfriend');"><a href="/matchGirlfriend"><i class="fas fa-angle-right"></i> 미래 여자친구 찾기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchBoyfriend');"><a href="/matchBoyfriend"><i class="fas fa-angle-right"></i> 미래 남자친구 찾기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchHouse');"><a href="/matchHouse"><i class="fas fa-angle-right"></i> 미래 나의집 찾기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchCar');"><a href="/matchCar"><i class="fas fa-angle-right"></i> 미래 나의 자동차 찾기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchPastlife');"><a href="/matchPastlife"><i class="fas fa-angle-right"></i> 나의 전생 찾기</a> <span style="color:red">New</span></td></tr>
# <tr class="touchsel"><td onclick="$(location).attr('href','/matchChosun');"><a href="/matchChosun"><i class="fas fa-angle-right"></i> 나의 조선시대 이름 찾기</a> <span style="color:red">New</span></td></tr>
# </table>
# </div>
# <div style="margin-top:7px">
# <table class="table table-bordered">
# <tr class="touchsel"><td onclick="$(location).attr('href','/?act=jjalbang_write');"><a href="/?act=jjalbang_write"><i class="fas fa-angle-right"></i> 짤방등록</a></td></tr>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="reloadwait" style="display:none;width:100%;text-align:center"></div>
# <!-- 태그 모달창 -->
# <div class="modal fade" id="searchModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h5 class="modal-title" id="myModalLabel"><span style="font-weight:bold">검색하기</span></h5>
# </div>
# <div class="modal-body text-center">
# <div class="clearfix">
# <div style="float:right;position: relative;left: -50%;">
# <div style="float:left;position: relative;left: 50%;"><input id="bbsrq" name="bbsrq" onkeypress="search_bbs(event,'key')" placeholder="검색할 키워드를 입력 ····" style="width:100%;font-weight:bold;font-size:16px;padding:5px;border: 1px solid #ccc;" type="search" value="행복"/></div>
# <div style="float:left;position: relative;left: 50%;padding-left:3px"><span class="btn btn-primary" onclick="search_bbs(event,'click')">검색</span></div>
# </div>
# </div>
# <div class="clearfix" style="padding:10px;text-align:center">
# <a class="btn btn-success touchitem" href="/tag/행복" style="font-weight:bold">#행복</a>
# <a class="btn btn-default touchitem" href="/action/rand_jjalbang.php" style="font-weight:bold">랜덤짤</a>
# </div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default btn-sm" data-dismiss="modal" type="button">창닫기</button>
# </div>
# </div>
# </div>
# </div>
# <!-- 태그 모달창 end -->
# <!-- 태그 모달창 -->
# <div class="modal fade" id="tagModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h5 class="modal-title" id="myModalLabel"><span style="font-weight:bold">#태그 리스트</span></h5>
# </div>
# <div class="modal-body text-center">
# <div style="overflow:scroll; width:100%; height:auto; padding:10px; ">
# <div class="row">
# <div class="text-left" style="padding:5px;font-size:17px"><strong>감정 태그</strong></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/분노" id="tag_분노" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">분노</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/경멸" id="tag_경멸" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">경멸</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/혐오" id="tag_혐오" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">혐오</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/공포" id="tag_공포" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">공포</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/행복" id="tag_행복" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">행복</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/중립" id="tag_중립" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">중립</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/슬픔" id="tag_슬픔" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">슬픔</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/emotion/놀람" id="tag_놀람" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">놀람</a></div>
# </div>
# <div class="row" style="padding-top:10px;">
# <div class="text-left" style="padding:5px;font-size:17px"><strong>추천태그</strong></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/최신" id="tag_최신" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">최신</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/화남" id="tag_화남" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">화남</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/좋아" id="tag_좋아" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">좋아</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/황당" id="tag_황당" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">황당</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/놀람" id="tag_놀람" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">놀람</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/닥쳐" id="tag_닥쳐" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">닥쳐</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/멘붕" id="tag_멘붕" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">멘붕</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/놀림" id="tag_놀림" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">놀림</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/칭찬" id="tag_칭찬" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">칭찬</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/눈물" id="tag_눈물" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">눈물</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/오글" id="tag_오글" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">오글</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/철컹" id="tag_철컹" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">철컹</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/움짤" id="tag_움짤" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">움짤</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/레전드" id="tag_레전드" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">레전드</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/정치" id="tag_정치" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">정치</a></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/기타" id="tag_기타" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap;font-weight:bold">기타</a></div>
# </div>
# <div class="row" style="padding-top:10px;padding-bottom:3px">
# <div class="text-left" style="padding:5px;font-size:17px"><strong>인기태그</strong></div>
# <div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/만능짤" id="tag_만능짤" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">만능짤</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/생성기" id="tag_생성기" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">생성기</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/무도" id="tag_무도" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">무도</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/무한도전" id="tag_무한도전" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">무한도전</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/웹툰" id="tag_웹툰" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">웹툰</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/둘리" id="tag_둘리" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">둘리</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/박명수" id="tag_박명수" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">박명수</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/유재석" id="tag_유재석" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">유재석</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/이미지" id="tag_이미지" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">이미지</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/도우너" id="tag_도우너" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">도우너</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/경찰" id="tag_경찰" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">경찰</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/빡침" id="tag_빡침" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">빡침</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/티비" id="tag_티비" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">티비</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/하이킥" id="tag_하이킥" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">하이킥</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default touchitem" href="/tag/아기공룡" id="tag_아기공룡" style="width:62px;overflow: hidden;text-overflow: ellipsis;white-space: nowrap">아기공룡</a></div><div class="col-xs-3 col-sm-2" style="padding:4px;margin-bottom:2px;border: 0px solid #ccc;"><a class="btn btn-sm btn-default t ...
# </div>
# </div>
# <div class="modal-footer">
# <button class="btn btn-default btn-sm" data-dismiss="modal" type="button">창닫기</button>
# </div>
# </div>
# </div>
# </div>
# <!-- 태그 모달창 end -->
# <!-- background-color:#47282A;color:#FFE600; -->
# <div style="padding-bottom:61px">
# <div class="clearfix" id="fixed-menu" style="background-color:#264d73;text-align:center;padding:10px;color:#513D3E;border-bottom: 0px solid #BEB0A8;box-shadow: 2px 2px 2px 0px #555555">
# <div class="row">
# <div class="col-xs-2 col-md-2" style="text-align:left"><a href="/"><img src="/img/jjalbang.today.128x128.png" style="width:34px"/></a></div>
# <div class="col-xs-10 col-md-10" style="text-align:right">
# <div class="input-group">
# <input class="form-control" id="bbsrq_bar" name="bbsrq" onkeypress="search_bbs_bar(event,'key')" placeholder="짤방검색" required="" type="search" value="행복"/>
# <div class="input-group-btn">
# <span class="btn btn-primary touchitem" onclick="search_bbs_bar(event,'click')"><i class="fas fa-search"></i></span>
# <span class="btn btn-default touchitem" data-target="#tagModal" data-toggle="modal">태그</span>
# <!-- span class="btn btn-default" onClick="$(location).attr('href','/function/최신/random')">랜덤</span -->
# <span class="btn btn-default touchitem" onclick="$(location).attr('href','/?act=jjalbang_write')">짤등록</span></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- 메뉴 -->
# <div class="menu_shadow" style="margin-top:5px;margin-left:10px;margin-right:10px">
# <table class="table table-bordered table-padding">
# <tr>
# <td class="text-center btn-padding cpointer" id="top_main_menu" onclick="$(location).attr('href','/');"><a href="/">상황별짤</a></td>
# <td class="text-center btn-padding cpointer" id="top_makejjal_menu" onclick="$(location).attr('href','/makejjal');"><a href="/makejjal">짤생성기</a></td>
# <td class="text-center btn-padding cpointer" id="top_emoticon_menu" onclick="$(location).attr('href','/emoticon');"><a href="/emoticon">텍스트짤</a></td>
# <td class="text-center btn-padding cpointer" id="top_jjalbangfonts_menu" onclick="$(location).attr('href','/jjalbangfonts');"><a href="/jjalbangfonts">폰트짤</a></td>
# <td class="text-center btn-padding cpointer" id="top_jjalbox_menu" onclick="$(location).attr('href','/?act=jjalbox.list');"><a href="/?act=jjalbox.list">짤박스</a></td>
# <td class="text-center btn-padding cpointer" data-target="#MainMenuModal" data-toggle="modal" onclick="document.location='#MainMenuModal'" width="36"><i class="fas fa-bars"></i></td>
# </tr>
# </table>
# </div>
# <div align="center">
# <div style="margin-top:20px;margin-bottom:10px;max-width:980px">
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1151764542261447"></script>
# <!-- jjalbang.today top 반응형 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1151764542261447" data-ad-format="auto" data-ad-slot="4507350989" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <div align="center" style="padding-top:0px;">
# <div class="container">
# <script>
# var clipboard = new ClipboardJS('.copybtn');
# clipboard.on( 'success', function() {
# 	msgAlert('msg_div','Copy Success!!',500,500);
# 	var selection = window.getSelection();
#   selection.removeAllRanges();
# } );
# clipboard.on( 'error', function() {         // 복사에 실패했을 때
#   // do something
# 	msgAlert('msg_div','Copy ERROR!!',500,1000);
# } );
#
# $(function () {$('#btn-upload').click(function (e) {e.preventDefault();$('#c_file').click();});});
# </script><script src="https://developers.kakao.com/sdk/js/kakao.min.js"></script>
# <script src="/js/clipboard.min.js"></script>
# <script src="/js/kakao.link.js"></script>
# <script src="/js/comm.js"></script>
# <script>
# function face_show(id,anger,contempt,disgust,fear,happiness,neutral,sadness,surprise)
# {
# 	var info_html = '<div style="width:300px;padding:6px;border: 1px solid #aaa">'+
# 	'<div><span>분노</span>:<span>'+anger+'</span></div>'+
# 	'<div><span>경멸</span>:<span>'+contempt+'</span></div>'+
# 	'<div><span>혐오</span>:<span>'+disgust+'</span></div>'+
# 	'<div><span>공포</span>:<span>'+fear+'</span></div>'+
# 	'<div><span>행복</span>:<span>'+happiness+'</span></div>'+
# 	'<div><span>중립</span>:<span>'+neutral+'</span></div>'+
# 	'<div><span>슬픔</span>:<span>'+sadness+'</span></div>'+
# 	'<div><span>놀람</span>:<span>'+surprise+'</span></div>'+
# 	'</div>';
# 	$('#'+id).html(info_html).toggle();
# }
# </script>
# <div style="padding-top:5px;">
# <span class="copybtn" data-clipboard-target="#orimgurl" onclick="msgAlert('msg_div','이미지 URL이 복사됐습니다. https://jjalbang.today/jjveU.jpg',1000,500);"><img alt="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기" id="image_url" src="https://jjalbang.today/files/jjalbox/2015/03/102_5516a431cdd60_924.jpg" style="max-width:100%" title="짤줍  짤  짤방  짤쇼핑  짤방모음  짤방줍기"/></span>
# </div>
# <div style="padding:15px"><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤줍">짤줍</a><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤">짤</a><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤방">짤방</a><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤쇼핑">짤쇼핑</a><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤방모음">짤방모음</a><a class="btn btn-default btn-default-tag touchitem" href="/tag/짤방줍기">짤방줍기</a></div>
# <div style="padding:15px"><a class="btn btn-sm btn-default" href="/jjalbangMake/924" style="border: 2px solid #555555;padding:20px"><span style="font-size:16px;font-weight:bold"> <i class="fas fa-magic" style="color:#ff3300;font-size:18px;padding-right:3px"></i> 위 짤방 편집하기</span></a>
# </div>
# <div>위 짤방 이미지를 원하는 글자나 이미지로 커스텀 할 수 있습니다.</div>
# <div style="padding-top:5px">
# <div align="center">
# <div style="width:100%;padding-top:15px;padding-bottom:35px;text-align:center;">
# <span style="padding:2px"><a href="/action/jjalbang_download.php?cnum=eU" target="_top"><img src="/image/sns/file2.png" style="width:50px;border: 1px solid #ccc;border-radius:20px"/></a></span>
# <span style="padding:2px"><a href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fjjalbang.today%2Fview%2F%ED%96%89%EB%B3%B5%2F924" target="_blank"><img src="/image/sns/facebook.png" style="width:50px;border-radius:20px"/></a></span>
# <span style="padding:2px"><a href="https://twitter.com/intent/tweet?url=https%3A%2F%2Fjjalbang.today%2Fview%2F%ED%96%89%EB%B3%B5%2F924&amp;text=%EC%A7%A4%EC%A4%8D++%EC%A7%A4++%EC%A7%A4%EB%B0%A9++%EC%A7%A4%EC%87%BC%ED%95%91++%EC%A7%A4%EB%B0%A9%EB%AA%A8%EC%9D%8C++%EC%A7%A4%EB%B0%A9%EC%A4%8D%EA%B8%B0-+%EC%98%A4%EB%8A%98%EC%9D%98%EC%A7%A4%EB%B0%A9&amp;hashtags=오늘의짤방" target="_blank"><img src="/image/sns/twitter.png" style="width:50px;border-radius:20px"/></a></span>
# </div>
# </div>
# <div class="clearfix"></div>
# <script>$(function() {Kakao.init('7d4d8a803b470c04c28ab56780e2becb');});</script>
# <div align="center" style="margin-top:0px;margin-bottom:20px">
# <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- jjalbang.today 반응형 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1151764542261447" data-ad-format="auto" data-ad-slot="2531031398" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# <div style="padding-top:20px">
# <div class="row">
# <div class="gal">
# <div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/4919"><img alt="설현 예쁜 걸그룹 몸매 움짤 광고 모델" src="/files/jjalboxthumb/2016/07/101_4919.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="설현 예쁜 걸그룹 몸매 움짤 광고 모델"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/4919"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/설현')">설현</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/예쁜')">예쁜</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/걸그룹')">걸그룹</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5781"><img alt="마녀사냥 신동엽 손가락질 에헤이 너희들 했네 했어 19금 드립" src="/files/jjalboxthumb/2016/09/95_5781.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="마녀사냥 신동엽 손가락질 에헤이 너희들 했네 했어 19금 드립"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5781"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/마녀사냥')">마녀사냥</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/신동엽')">신동엽</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/손가락질')">손가락질</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5054"><img alt="션 오프리 모델 랭킹 1위 잘생긴 움짤 노란옷" src="/files/jjalboxthumb/2016/08/102_5054.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="션 오프리 모델 랭킹 1위 잘생긴 움짤 노란옷"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5054"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/션')">션</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/오프리')">오프리</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/모델')">모델</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/1880"><img alt="오글 오글오글 손발 실사버전 실사" src="/files/jjalboxthumb/2015/03/94_1880.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="오글 오글오글 손발 실사버전 실사"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/1880"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/오글')">오글</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/오글오글')">오글오글</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/손발')">손발</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5173"><img alt="스마일 웃으면서 욕하기 장나라 웃는얼굴 ㅅㅂ ㅆㅂ 시바 울보면서 욕연습 " src="/files/jjalboxthumb/2016/08/85_5173.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="스마일 웃으면서 욕하기 장나라 웃는얼굴 ㅅㅂ ㅆㅂ 시바 울보면서 욕연습 "/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5173"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/스마일')">스마일</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/웃으면서')">웃으면서</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/욕하기')">욕하기</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5049"><img alt="훈남 모델 화장하는 모습" src="/files/jjalboxthumb/2016/08/102_5049.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="훈남 모델 화장하는 모습"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5049"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/훈남')">훈남</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/모델')">모델</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/화장하는')">화장하는</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5385"><img alt="최고 칭찬 만수르 부자의 기운 니가 최고다 엄지척" src="/files/jjalboxthumb/2016/08/101_5385.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="최고 칭찬 만수르 부자의 기운 니가 최고다 엄지척"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5385"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/최고')">최고</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/칭찬')">칭찬</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/만수르')">만수르</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5162"><img alt="나연 트와이스 연예인 여자 귀여운 예쁜 표정 애교 걸그룹 움짤" src="/files/jjalboxthumb/2016/08/102_5162.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="나연 트와이스 연예인 여자 귀여운 예쁜 표정 애교 걸그룹 움짤"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5162"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/나연')">나연</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/트와이스')">트와이스</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/연예인')">연예인</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/6849"><img alt="고전 레전드 명짤 택배왔어요 원본 큰거 웃음 뛰어오는 모습 빠른배송 택배" src="/files/jjalboxthumb/2018/01/102_6849.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="고전 레전드 명짤 택배왔어요 원본 큰거 웃음 뛰어오는 모습 빠른배송 택배"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/6849"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/고전')">고전</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/레전드')">레전드</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/명짤')">명짤</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/6442"><img alt="엄현경 얼굴 잘생김 잘생긴 남자 남자친구 얼굴본다 잘생긴사람 오징이 싫어" src="/files/jjalboxthumb/2017/12/102_6442.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="엄현경 얼굴 잘생김 잘생긴 남자 남자친구 얼굴본다 잘생긴사람 오징이 싫어"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/6442"></a></div>
# ...
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5685"><img alt="하연수 애교 움짤 니꺼 작아도 화이팅 이라고 하는듯" src="/files/jjalboxthumb/2016/09/86_5685.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="하연수 애교 움짤 니꺼 작아도 화이팅 이라고 하는듯"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5685"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/하연수')">하연수</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/애교')">애교</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/움짤')">움짤</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/6466"><img alt="예스 내가했어 해냈어 오예 기분 좋아 good 여자 기분업" src="/files/jjalboxthumb/2017/12/102_6466.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="예스 내가했어 해냈어 오예 기분 좋아 good 여자 기분업"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/6466"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/예스')">예스</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/내가했어')">내가했어</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/해냈어')">해냈어</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5063"><img alt="모델 남자 여자들을 위한 움짤" src="/files/jjalboxthumb/2016/08/102_5063.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="모델 남자 여자들을 위한 움짤"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5063"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/모델')">모델</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/남자')">남자</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/여자들을')">여자들을</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/4999"><img alt="카메라 홍시아 김지연 웃음 미소 샤방" src="/files/jjalboxthumb/2016/08/102_4999.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="카메라 홍시아 김지연 웃음 미소 샤방"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/4999"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/카메라')">카메라</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/홍시아')">홍시아</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/김지연')">김지연</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/4898"><img alt="경영사마 허경영 예산이 부족한 것이 아닙니다 국가 도둑놈들 많은 것입니다" src="/files/jjalboxthumb/2016/07/107_4898.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="경영사마 허경영 예산이 부족한 것이 아닙니다 국가 도둑놈들 많은 것입니다"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/4898"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/경영사마')">경영사마</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/허경영')">허경영</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/예산이')">예산이</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/2649"><img alt="박신혜 움짤 강아지 귀여운 예쁜 여자 개" src="/files/jjalboxthumb/2015/03/96_2649.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="박신혜 움짤 강아지 귀여운 예쁜 여자 개"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/2649"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/박신혜')">박신혜</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/움짤')">움짤</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/강아지')">강아지</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/6304"><img alt="샘슈내" src="/files/jjalboxthumb/2017/08/102_6304.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="샘슈내"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/6304"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/샘슈내')">샘슈내</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5899"><img alt="악수 싸인 호흡 환상 어쩌라고 뭘할건데" src="/files/jjalboxthumb/2016/10/86_5899.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="악수 싸인 호흡 환상 어쩌라고 뭘할건데"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5899"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/악수')">악수</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/싸인')">싸인</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/호흡')">호흡</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/5499"><img alt="애교 보니 하니 귀여운 이수민" src="/files/jjalboxthumb/2016/08/102_5499.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="애교 보니 하니 귀여운 이수민"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/5499"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/애교')">애교</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/보니')">보니</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/하니')">하니</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/3002"><img alt="분위기 개똥 같구먼 무한도전 못친소 윤종신 황당하네 황당" src="/files/jjalboxthumb/2015/04/87_3002.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="분위기 개똥 같구먼 무한도전 못친소 윤종신 황당하네 황당"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/3002"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/분위기')">분위기</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/개똥')">개똥</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/같구먼')">같구먼</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/3441"><img alt="하이파이브 잘했어 좋아 그래 그거야 셀프 솔로" src="/files/jjalboxthumb/2015/07/102_3441.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="하이파이브 잘했어 좋아 그래 그거야 셀프 솔로"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/3441"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/하이파이브')">하이파이</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/잘했어')">잘했어</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/좋아')">좋아</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/6608"><img alt="손나은 에이핑크 레전드 역대급 드라마 장면 굴욕 표정 연기" src="/files/jjalboxthumb/2017/12/102_6608.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="손나은 에이핑크 레전드 역대급 드라마 장면 굴욕 표정 연기"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/6608"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/손나은')">손나은</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/에이핑크')">에이핑크</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/레전드')">레전드</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/1136"><img alt="웃음 프로게이머 게임 " src="/files/jjalboxthumb/2015/03/86_1136.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="웃음 프로게이머 게임 "/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/1136"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/웃음')">웃음</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/프로게이머')">프로게이</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/게임')">게임</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/1125"><img alt="웃음 밤이 외롭던데요 이효리 미소 웃음 잇몸 레전드" src="/files/jjalboxthumb/2015/03/86_1125.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="웃음 밤이 외롭던데요 이효리 미소 웃음 잇몸 레전드"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/1125"></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/웃음')">웃음</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/밤이')">밤이</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/외롭던데요')">외롭던데</span></div>
# </div>
# </div><div class="col-xs-6 col-sm-4 col-md-3 col-lg-3" style="padding:5px;"><div style="position: relative"><a href="/emotionview/행복/1908"><img alt="부끄 움짤 소녀시대 태연 귀여운 탱구" src="/files/jjalboxthumb/2015/03/94_1908.jpg" style="max-width:230px;border: 0px solid #ddd;border-radius:0px" title="부끄 움짤 소녀시대 태연 귀여운 탱구"/></a>
# <div class="jjalbang_content"><a href="/emotionview/행복/1908"><span><img src="/image/icon/gifmark.png" style="width:30px"/></span></a></div>
# <div class="jjalbang_content_bottom"><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/부끄')">부끄</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/움짤')">움짤</span><span class="btn btn-xs btn-default btn-default-s-tag touchitem" onclick="$(location).attr('href','/tag/소녀시대')">소녀시대</span></div>
# </div>
# </div><span id="jjal_list"></span>
# </div>
# </div>
# <script>
# var page = 2;
# var page_end_check = false;
# function ajax_print(tag,mode)
# {
# 	$('#nextwait').show();
# 	var url = "/ajax/jjalbang_list.php?tag="+tag+"&page="+page+"&mode="+mode;
# 	page++;
# 	var jjal_list_data  = '';
# 	$(document).ready(function(){
# 	$.ajax({
# 	type: "GET",
# 	url: url,
# 	dataType: "json",
# 	success: function(data) {
# 	$.each(data, function(i, post){
# 		$('#nextwait').hide();
# 		if(post.page_end == "end")
# 		{
# 			$('#more_text').html('page end');
# 			page_end_check = true;
# 		}
# 		else
# 		{
# 			jjal_list_data += post.list_jjal;
# 			page_end_check = false;
# 		}
# 	});
#
# 	$('#jjal_list').append(jjal_list_data);
#
# 	}
#
# 	});
# 	});
# }
# </script></div>
# <script>
# var clipboard = new ClipboardJS('.copybtn');
# clipboard.on( 'success', function() {
# 	msgAlert('msg_div','Copy Success!!',500,500);
# 	var selection = window.getSelection();
#   selection.removeAllRanges();
# } );
# clipboard.on( 'error', function() {         // 복사에 실패했을 때
#   // do something
# 	msgAlert('msg_div','Copy ERROR!!',500,1000);
# } );
#
# 		$('#top_main_menu').addClass('sub_select');
#
# 	$('.touchitem').bind('touchstart',function(event){
#     $(this).css('background-color', '#aaaaaa');
# 	});
#
# 	$('.touchitem').bind('touchend',function(event){
#     $(this).css('background-color', '#fff');
# 	});
#
# 	$('.touchitem').bind('touchmove',function(event){
#     $(this).css('background-color', '#fff');
# 	});
#
# 	$("#tag_행복").addClass('tag_select');
#
# $("img.lazy").lazyload({
#     threshold : 300,        //뷰포트에 보이기 300px 전에 미리 로딩
#     effect : "fadeIn"       //효과
# });
# </script>
# <div align="center">
# <div style="margin-top:20px;margin-bottom:10px;max-width:980px">
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-1151764542261447"></script>
# <!-- jjalbang.today top 반응형 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-1151764542261447" data-ad-format="auto" data-ad-slot="4507350989" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-45868779-6"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-45868779-6');
# </script>
# </div>
# </div>
# <span onclick="$('html, body').animate({scrollTop:0},300);" style="display:scroll;position:fixed;bottom:43px;right:10px;padding:6px;font-size:12px;color:#555555;background-color:#cccccc;opacity: 0.5;border-radius: 7px;" title="맨 위로"><i class="fas fa-chevron-up fa-lg"></i></span>
# <span onclick="$('html, body').animate({scrollTop:$(document).height()},300);" style="display:scroll;position:fixed;bottom:10px;right:10px;padding:6px;font-size:12px;color:#555555;background-color:#cccccc;opacity: 0.5;border-radius: 7px;" title="맨 아래로"><i class="fas fa-chevron-down fa-lg"></i></span>
# <div class="msg_center" id="msg_div"></div>
# <div style="text-align:center;padding:30px;font-size:12px"><i class="glyphicon glyphicon-copyright-mark"></i> jjalbang.today<br/><br/>jjalbang.today@gmail.com</div>
# </div></body>
# </html>

# %%
import datetime

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        driver.execute_script('window.scrollTo(0, 5000);')
        if datetime.datetime.now() > end:
            break

doScrollDown(5)

# %%
for i in range(100):
    try:
        box = driver.find_element_by_xpath('//*[@id="divReviewPageMore"]/div[1]/a')
        box.click()
    except:
        break

# %%
a = driver.find_elements_by_css_selector("a.Ere_sub_gray8.Ere_fs13.Ere_PR10")
user_site = set()
for i in a:
    user_site.add(i.get_attribute('href'))

# %%
import requests
from bs4 import BeautifulSoup

url = list(user_site)[0]

response = requests.get(url)


html = response.text
soup = BeautifulSoup(html, 'html.parser')
c = soup.find_all("a","bo")
for i in c:
    print(i.text)
